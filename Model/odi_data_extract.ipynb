# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
# Creating an empty list to store file names with their paths
names_of_files = []

# Iterating through the files in the 'odi_dataset' directory
for file in os.listdir('odi_dataset'):
    names_of_files.append(os.path.join('odi_dataset', file)) # Appending the absolute path of each file to the list

# %%
# Showing the names of the files in the directory
names_of_files[0:5]
# Out:
# ['odi_dataset\\1000887.yaml',
#  'odi_dataset\\1000889.yaml',
#  'odi_dataset\\1000891.yaml',
#  'odi_dataset\\1000893.yaml',
#  'odi_dataset\\1000895.yaml']

# %%
# Initializing an empty list to store DataFrame
dataframe_1 = pd.DataFrame()

# Initializing a counter for a new column - 'match_id'
counter = 1

# Iterating through the files with a progress bar(tqdm)
for file in tqdm(names_of_files):
    with open(file, 'r') as f:
        # Load YAML file, normalize to DataFrame, and add 'match_id' column
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        dataframe_1 = pd.concat([dataframe_1, df], ignore_index=True)
        counter += 1

# Display the resulting DataFrame
dataframe_1
# Out:
# 100%|██████████| 2822/2822 [24:12<00:00,  1.94it/s]
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
# 3     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# ...                                                 ...                ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
# 2821  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-01-14              2                    6   Brisbane
# 1      2017-01-18              1                    6        NaN
# 2      2017-01-21              1                    6      Perth
# 3      2017-01-22              1                    6        NaN
# 4      2017-01-28              1                    6        NaN
# ...           ...            ...                  ...        ...
# 2817   2016-07-13              1                    6    Belfast
# 2818   2016-07-20              1                    6    Belfast
# 2819   2016-07-20              1                    6    Belfast
# 2820   2016-08-20              1                    6  Edinburgh
# 2821   2016-08-20              1                    6  Edinburgh
#
#         info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
# 0     [2017-01-13]        male             ODI                  92.0  ...
# 1     [2017-01-15]        male             ODI                   NaN  ...
# 2     [2017-01-19]        male             ODI                   NaN  ...
# 3     [2017-01-22]        male             ODI                  86.0  ...
# 4     [2017-01-26]        male             ODI                  57.0  ...
# ...            ...         ...             ...                   ...  ...
# 2817  [2016-07-12]        male             ODI                  39.0  ...
# 2818  [2016-07-17]        male             ODI                  79.0  ...
# 2819  [2016-07-19]        male             ODI                  12.0  ...
# 2820  [2016-08-14]        male             ODI                  98.0  ...
# 2821  [2016-08-16]        male             ODI                   NaN  ...
#
#      info.registry.people.SP Terry  info.registry.people.DJ Worrall  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
# ...                            ...                              ...
# 2817                           NaN                              NaN
# 2818                      7f87204d                              NaN
# 2819                      7f87204d                              NaN
# 2820                           NaN                              NaN
# 2821                           NaN                              NaN
#
#      info.registry.people.CP Tremain info.registry.people.JM Mennie  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 2817                             NaN                            NaN
# 2818                             NaN                            NaN
# 2819                             NaN                            NaN
# 2820                             NaN                            NaN
# 2821                             NaN                            NaN
#
#      info.registry.people.DS Weerakkody info.registry.people.IG Warne  \
# 0                                   NaN                           NaN
# 1                                   NaN                           NaN
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                   NaN                           NaN
# ...                                 ...                           ...
# 2817                                NaN                           NaN
# 2818                                NaN                           NaN
# 2819                                NaN                           NaN
# 2820                                NaN                           NaN
# 2821                                NaN                           NaN
#
#      info.registry.people.Rokhan Barakzai info.registry.people.CC Dalton  \
# 0                                     NaN                            NaN
# 1                                     NaN                            NaN
# 2                                     NaN                            NaN
# 3                                     NaN                            NaN
# 4                                     NaN                            NaN
# ...                                   ...                            ...
# 2817                                  NaN                            NaN
# 2818                                  NaN                            NaN
# 2819                                  NaN                            NaN
# 2820                                  NaN                            NaN
# 2821                                  NaN                            NaN
#
#      info.registry.people.S Wijesundera info.registry.people.U Raymond-Hoey
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ...                                 ...                                 ...
# 2817                                NaN                                 NaN
# 2818                                NaN                                 NaN
# 2819                                NaN                                 NaN
# 2820                                NaN                                 NaN
# 2821                                NaN                                 NaN
#
# [2822 rows x 2935 columns]

# %%
# Checking if any column names contain 'weather'
weather_columns = [col for col in dataframe_1.columns if 'weather' in col.lower()]

# Checking if any column names contain 'condition'
condition_columns = [col for col in dataframe_1.columns if 'condition' in col.lower()]

# Checking if any column names contain 'pitch'
pitch_columns = [col for col in dataframe_1.columns if 'pitch' in col.lower()]

# Displaying the columns containing 'weather'
print(weather_columns)

# Displaying the columns containing 'condition'
print(condition_columns)

# Displaying the columns containing 'pitch'
print(pitch_columns)
# Out:
# []
# []
# ['info.registry.people.OL Pitcher', 'info.registry.people.ADJ Pitcher', 'info.registry.people.AR Pitcher']

# %%
# Dropping 'info.registry.' type columns
dataframe_1 = dataframe_1.loc[:, ~dataframe_1.columns.str.startswith('info.registry.people.')]

# %%
dataframe_1
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
# 3     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# ...                                                 ...                ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
# 2821  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-01-14              2                    6   Brisbane
# 1      2017-01-18              1                    6        NaN
# 2      2017-01-21              1                    6      Perth
# 3      2017-01-22              1                    6        NaN
# 4      2017-01-28              1                    6        NaN
# ...           ...            ...                  ...        ...
# 2817   2016-07-13              1                    6    Belfast
# 2818   2016-07-20              1                    6    Belfast
# 2819   2016-07-20              1                    6    Belfast
# 2820   2016-08-20              1                    6  Edinburgh
# 2821   2016-08-20              1                    6  Edinburgh
#
#         info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
# 0     [2017-01-13]        male             ODI                  92.0  ...
# 1     [2017-01-15]        male             ODI                   NaN  ...
# 2     [2017-01-19]        male             ODI                   NaN  ...
# 3     [2017-01-22]        male             ODI                  86.0  ...
# 4     [2017-01-26]        male             ODI                  57.0  ...
# ...            ...         ...             ...                   ...  ...
# 2817  [2016-07-12]        male             ODI                  39.0  ...
# 2818  [2016-07-17]        male             ODI                  79.0  ...
# 2819  [2016-07-19]        male             ODI                  12.0  ...
# 2820  [2016-08-14]        male             ODI                  98.0  ...
# 2821  [2016-08-16]        male             ODI                   NaN  ...
#
#      info.supersubs.Bangladesh  info.supersubs.New Zealand  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ...                        ...                         ...
# 2817                       NaN                         NaN
# 2818                       NaN                         NaN
# 2819                       NaN                         NaN
# 2820                       NaN                         NaN
# 2821                       NaN                         NaN
#
#      info.supersubs.India info.players.ICC World XI  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
# ...                   ...                       ...
# 2817                  NaN                       NaN
# 2818                  NaN                       NaN
# 2819                  NaN                       NaN
# 2820                  NaN                       NaN
# 2821                  NaN                       NaN
#
#      info.supersubs.ICC World XI info.supersubs.South Africa  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 2817                         NaN                         NaN
# 2818                         NaN                         NaN
# 2819                         NaN                         NaN
# 2820                         NaN                         NaN
# 2821                         NaN                         NaN
#
#      info.supersubs.Pakistan info.supersubs.West Indies info.players.Bermuda  \
# 0                        NaN                        NaN                  NaN
# 1                        NaN                        NaN                  NaN
# 2                        NaN                        NaN                  NaN
# 3                        NaN                        NaN                  NaN
# 4                        NaN                        NaN                  NaN
# ...                      ...                        ...                  ...
# 2817                     NaN                        NaN                  NaN
# 2818                     NaN                        NaN                  NaN
# 2819                     NaN                        NaN                  NaN
# 2820                     NaN                        NaN                  NaN
# 2821                     NaN                        NaN                  NaN
#
#      info.players.Kenya
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 2817                NaN
# 2818                NaN
# 2819                NaN
# 2820                NaN
# 2821                NaN
#
# [2822 rows x 67 columns]

# %%
# Dropping 'info.supersubs.' type columns
dataframe_1 = dataframe_1.loc[:, ~dataframe_1.columns.str.startswith('info.supersubs.')]

# %%
dataframe_1
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
# 3     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# ...                                                 ...                ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
# 2821  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-01-14              2                    6   Brisbane
# 1      2017-01-18              1                    6        NaN
# 2      2017-01-21              1                    6      Perth
# 3      2017-01-22              1                    6        NaN
# 4      2017-01-28              1                    6        NaN
# ...           ...            ...                  ...        ...
# 2817   2016-07-13              1                    6    Belfast
# 2818   2016-07-20              1                    6    Belfast
# 2819   2016-07-20              1                    6    Belfast
# 2820   2016-08-20              1                    6  Edinburgh
# 2821   2016-08-20              1                    6  Edinburgh
#
#         info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
# 0     [2017-01-13]        male             ODI                  92.0  ...
# 1     [2017-01-15]        male             ODI                   NaN  ...
# 2     [2017-01-19]        male             ODI                   NaN  ...
# 3     [2017-01-22]        male             ODI                  86.0  ...
# 4     [2017-01-26]        male             ODI                  57.0  ...
# ...            ...         ...             ...                   ...  ...
# 2817  [2016-07-12]        male             ODI                  39.0  ...
# 2818  [2016-07-17]        male             ODI                  79.0  ...
# 2819  [2016-07-19]        male             ODI                  12.0  ...
# 2820  [2016-08-14]        male             ODI                  98.0  ...
# 2821  [2016-08-16]        male             ODI                   NaN  ...
#
#      info.players.Oman  info.players.Netherlands info.players.Thailand  \
# 0                  NaN                       NaN                   NaN
# 1                  NaN                       NaN                   NaN
# 2                  NaN                       NaN                   NaN
# 3                  NaN                       NaN                   NaN
# 4                  NaN                       NaN                   NaN
# ...                ...                       ...                   ...
# 2817               NaN                       NaN                   NaN
# 2818               NaN                       NaN                   NaN
# 2819               NaN                       NaN                   NaN
# 2820               NaN                       NaN                   NaN
# 2821               NaN                       NaN                   NaN
#
#      info.players.Canada info.players.Jersey info.players.Africa XI  \
# 0                    NaN                 NaN                    NaN
# 1                    NaN                 NaN                    NaN
# 2                    NaN                 NaN                    NaN
# 3                    NaN                 NaN                    NaN
# 4                    NaN                 NaN                    NaN
# ...                  ...                 ...                    ...
# 2817                 NaN                 NaN                    NaN
# 2818                 NaN                 NaN                    NaN
# 2819                 NaN                 NaN                    NaN
# 2820                 NaN                 NaN                    NaN
# 2821                 NaN                 NaN                    NaN
#
#      info.players.Asia XI info.players.ICC World XI info.players.Bermuda  \
# 0                     NaN                       NaN                  NaN
# 1                     NaN                       NaN                  NaN
# 2                     NaN                       NaN                  NaN
# 3                     NaN                       NaN                  NaN
# 4                     NaN                       NaN                  NaN
# ...                   ...                       ...                  ...
# 2817                  NaN                       NaN                  NaN
# 2818                  NaN                       NaN                  NaN
# 2819                  NaN                       NaN                  NaN
# 2820                  NaN                       NaN                  NaN
# 2821                  NaN                       NaN                  NaN
#
#      info.players.Kenya
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 2817                NaN
# 2818                NaN
# 2819                NaN
# 2820                NaN
# 2821                NaN
#
# [2822 rows x 54 columns]

# %%
# Dropping 'info.players.' type columns
dataframe_1 = dataframe_1.loc[:, ~dataframe_1.columns.str.startswith('info.players.')]

# %%
dataframe_1
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...               0.91
# 3     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# ...                                                 ...                ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...               0.91
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...               0.91
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...               0.91
# 2821  [{'1st innings': {'team': 'United Arab Emirate...               0.91
#
#      meta.created  meta.revision  info.balls_per_over  info.city  \
# 0      2017-01-14              2                    6   Brisbane
# 1      2017-01-18              1                    6        NaN
# 2      2017-01-21              1                    6      Perth
# 3      2017-01-22              1                    6        NaN
# 4      2017-01-28              1                    6        NaN
# ...           ...            ...                  ...        ...
# 2817   2016-07-13              1                    6    Belfast
# 2818   2016-07-20              1                    6    Belfast
# 2819   2016-07-20              1                    6    Belfast
# 2820   2016-08-20              1                    6  Edinburgh
# 2821   2016-08-20              1                    6  Edinburgh
#
#         info.dates info.gender info.match_type  info.outcome.by.runs  ...  \
# 0     [2017-01-13]        male             ODI                  92.0  ...
# 1     [2017-01-15]        male             ODI                   NaN  ...
# 2     [2017-01-19]        male             ODI                   NaN  ...
# 3     [2017-01-22]        male             ODI                  86.0  ...
# 4     [2017-01-26]        male             ODI                  57.0  ...
# ...            ...         ...             ...                   ...  ...
# 2817  [2016-07-12]        male             ODI                  39.0  ...
# 2818  [2016-07-17]        male             ODI                  79.0  ...
# 2819  [2016-07-19]        male             ODI                  12.0  ...
# 2820  [2016-08-14]        male             ODI                  98.0  ...
# 2821  [2016-08-16]        male             ODI                   NaN  ...
#
#           info.toss.winner                 info.umpires  \
# 0                Australia  [MD Martell, C Shamshuddin]
# 1                Australia      [CB Gaffaney, P Wilson]
# 2                Australia      [SD Fry, C Shamshuddin]
# 3                Australia    [CB Gaffaney, MD Martell]
# 4                Australia      [SD Fry, C Shamshuddin]
# ...                    ...                          ...
# 2817               Ireland        [AJ Neill, IN Ramage]
# 2818           Afghanistan    [AJ Neill, C Shamshuddin]
# 2819           Afghanistan     [R Black, C Shamshuddin]
# 2820  United Arab Emirates      [DA Haggo, M Hawthorne]
# 2821  United Arab Emirates      [DA Haggo, M Hawthorne]
#
#                                         info.venue match_id  \
# 0           Brisbane Cricket Ground, Woolloongabba        1
# 1                         Melbourne Cricket Ground        2
# 2     Western Australia Cricket Association Ground        3
# 3                            Sydney Cricket Ground        4
# 4                                    Adelaide Oval        5
# ...                                            ...      ...
# 2817          Civil Service Cricket Club, Stormont     2818
# 2818          Civil Service Cricket Club, Stormont     2819
# 2819          Civil Service Cricket Club, Stormont     2820
# 2820     Grange Cricket Club Ground, Raeburn Place     2821
# 2821     Grange Cricket Club Ground, Raeburn Place     2822
#
#      info.outcome.by.wickets info.outcome.result info.outcome.method  \
# 0                        NaN                 NaN                 NaN
# 1                        6.0                 NaN                 NaN
# 2                        7.0                 NaN                 NaN
# 3                        NaN                 NaN                 NaN
# 4                        NaN                 NaN                 NaN
# ...                      ...                 ...                 ...
# 2817                     NaN                 NaN                 NaN
# 2818                     NaN                 NaN                 NaN
# 2819                     NaN                 NaN                 NaN
# 2820                     NaN                 NaN                 NaN
# 2821                     7.0                 NaN                 NaN
#
#      info.neutral_venue  info.match_type_number  info.outcome.eliminator
# 0                   NaN                     NaN                      NaN
# 1                   NaN                     NaN                      NaN
# 2                   NaN                     NaN                      NaN
# 3                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
# ...                 ...                     ...                      ...
# 2817                NaN                     NaN                      NaN
# 2818                NaN                     NaN                      NaN
# 2819                NaN                     NaN                      NaN
# 2820                NaN                     NaN                      NaN
# 2821                NaN                     NaN                      NaN
#
# [2822 rows x 25 columns]

# %%
# Dropping 'meta.data_version', 'meta.created', 'meta.revision' columns
dataframe_1 = dataframe_1.drop(columns=['meta.data_version', 'meta.created', 'meta.revision'])

# %%
dataframe_1
# Out:
#                                                 innings  info.balls_per_over  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 1     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...                    6
# 3     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 4     [{'1st innings': {'team': 'Australia', 'delive...                    6
# ...                                                 ...                  ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...                    6
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...                    6
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...                    6
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...                    6
# 2821  [{'1st innings': {'team': 'United Arab Emirate...                    6
#
#       info.city    info.dates info.gender info.match_type  \
# 0      Brisbane  [2017-01-13]        male             ODI
# 1           NaN  [2017-01-15]        male             ODI
# 2         Perth  [2017-01-19]        male             ODI
# 3           NaN  [2017-01-22]        male             ODI
# 4           NaN  [2017-01-26]        male             ODI
# ...         ...           ...         ...             ...
# 2817    Belfast  [2016-07-12]        male             ODI
# 2818    Belfast  [2016-07-17]        male             ODI
# 2819    Belfast  [2016-07-19]        male             ODI
# 2820  Edinburgh  [2016-08-14]        male             ODI
# 2821  Edinburgh  [2016-08-16]        male             ODI
#
#       info.outcome.by.runs info.outcome.winner  info.overs  \
# 0                     92.0           Australia          50
# 1                      NaN            Pakistan          50
# 2                      NaN           Australia          50
# 3                     86.0           Australia          50
# 4                     57.0           Australia          50
# ...                    ...                 ...         ...
# 2817                  39.0         Afghanistan          50
# 2818                  79.0         Afghanistan          50
# 2819                  12.0             Ireland          50
# 2820                  98.0            Scotland          50
# 2821                   NaN            Scotland          50
#
#      info.player_of_match  ...      info.toss.winner  \
# 0               [MS Wade]  ...             Australia
# 1       [Mohammad Hafeez]  ...             Australia
# 2             [SPD Smith]  ...             Australia
# 3             [DA Warner]  ...             Australia
# 4             [DA Warner]  ...             Australia
# ...                   ...  ...                   ...
# 2817                  NaN  ...               Ireland
# 2818                  NaN  ...           Afghanistan
# 2819                  NaN  ...           Afghanistan
# 2820                  NaN  ...  United Arab Emirates
# 2821                  NaN  ...  United Arab Emirates
#
#                      info.umpires  \
# 0     [MD Martell, C Shamshuddin]
# 1         [CB Gaffaney, P Wilson]
# 2         [SD Fry, C Shamshuddin]
# 3       [CB Gaffaney, MD Martell]
# 4         [SD Fry, C Shamshuddin]
# ...                           ...
# 2817        [AJ Neill, IN Ramage]
# 2818    [AJ Neill, C Shamshuddin]
# 2819     [R Black, C Shamshuddin]
# 2820      [DA Haggo, M Hawthorne]
# 2821      [DA Haggo, M Hawthorne]
#
#                                         info.venue match_id  \
# 0           Brisbane Cricket Ground, Woolloongabba        1
# 1                         Melbourne Cricket Ground        2
# 2     Western Australia Cricket Association Ground        3
# 3                            Sydney Cricket Ground        4
# 4                                    Adelaide Oval        5
# ...                                            ...      ...
# 2817          Civil Service Cricket Club, Stormont     2818
# 2818          Civil Service Cricket Club, Stormont     2819
# 2819          Civil Service Cricket Club, Stormont     2820
# 2820     Grange Cricket Club Ground, Raeburn Place     2821
# 2821     Grange Cricket Club Ground, Raeburn Place     2822
#
#      info.outcome.by.wickets  info.outcome.result  info.outcome.method  \
# 0                        NaN                  NaN                  NaN
# 1                        6.0                  NaN                  NaN
# 2                        7.0                  NaN                  NaN
# 3                        NaN                  NaN                  NaN
# 4                        NaN                  NaN                  NaN
# ...                      ...                  ...                  ...
# 2817                     NaN                  NaN                  NaN
# 2818                     NaN                  NaN                  NaN
# 2819                     NaN                  NaN                  NaN
# 2820                     NaN                  NaN                  NaN
# 2821                     7.0                  NaN                  NaN
#
#      info.neutral_venue info.match_type_number  info.outcome.eliminator
# 0                   NaN                    NaN                      NaN
# 1                   NaN                    NaN                      NaN
# 2                   NaN                    NaN                      NaN
# 3                   NaN                    NaN                      NaN
# 4                   NaN                    NaN                      NaN
# ...                 ...                    ...                      ...
# 2817                NaN                    NaN                      NaN
# 2818                NaN                    NaN                      NaN
# 2819                NaN                    NaN                      NaN
# 2820                NaN                    NaN                      NaN
# 2821                NaN                    NaN                      NaN
#
# [2822 rows x 22 columns]

# %%
#  Dropping 'info.outcome.eliminator', 'info.outcome.result', 'info.outcome.method', 'info.neutral_venue', 'info.match_type_number', 'info.outcome.by.wickets', 'info.outcome.by.runs' columns
columns_to_drop = ['info.outcome.eliminator', 'info.outcome.result', 'info.outcome.method', 'info.neutral_venue', 'info.match_type_number', 'info.outcome.by.wickets', 'info.outcome.by.runs']

# %%
dataframe_1 = dataframe_1.drop(columns=columns_to_drop)

# %%
dataframe_1
# Out:
#                                                 innings  info.balls_per_over  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 1     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...                    6
# 3     [{'1st innings': {'team': 'Australia', 'delive...                    6
# 4     [{'1st innings': {'team': 'Australia', 'delive...                    6
# ...                                                 ...                  ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...                    6
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...                    6
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...                    6
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...                    6
# 2821  [{'1st innings': {'team': 'United Arab Emirate...                    6
#
#       info.city    info.dates info.gender info.match_type info.outcome.winner  \
# 0      Brisbane  [2017-01-13]        male             ODI           Australia
# 1           NaN  [2017-01-15]        male             ODI            Pakistan
# 2         Perth  [2017-01-19]        male             ODI           Australia
# 3           NaN  [2017-01-22]        male             ODI           Australia
# 4           NaN  [2017-01-26]        male             ODI           Australia
# ...         ...           ...         ...             ...                 ...
# 2817    Belfast  [2016-07-12]        male             ODI         Afghanistan
# 2818    Belfast  [2016-07-17]        male             ODI         Afghanistan
# 2819    Belfast  [2016-07-19]        male             ODI             Ireland
# 2820  Edinburgh  [2016-08-14]        male             ODI            Scotland
# 2821  Edinburgh  [2016-08-16]        male             ODI            Scotland
#
#       info.overs info.player_of_match                        info.teams  \
# 0             50            [MS Wade]             [Australia, Pakistan]
# 1             50    [Mohammad Hafeez]             [Australia, Pakistan]
# 2             50          [SPD Smith]             [Australia, Pakistan]
# 3             50          [DA Warner]             [Australia, Pakistan]
# 4             50          [DA Warner]             [Australia, Pakistan]
# ...          ...                  ...                               ...
# 2817          50                  NaN            [Ireland, Afghanistan]
# 2818          50                  NaN            [Ireland, Afghanistan]
# 2819          50                  NaN            [Ireland, Afghanistan]
# 2820          50                  NaN  [Scotland, United Arab Emirates]
# 2821          50                  NaN  [Scotland, United Arab Emirates]
#
#      info.toss.decision      info.toss.winner                 info.umpires  \
# 0                   bat             Australia  [MD Martell, C Shamshuddin]
# 1                   bat             Australia      [CB Gaffaney, P Wilson]
# 2                 field             Australia      [SD Fry, C Shamshuddin]
# 3                   bat             Australia    [CB Gaffaney, MD Martell]
# 4                   bat             Australia      [SD Fry, C Shamshuddin]
# ...                 ...                   ...                          ...
# 2817              field               Ireland        [AJ Neill, IN Ramage]
# 2818                bat           Afghanistan    [AJ Neill, C Shamshuddin]
# 2819              field           Afghanistan     [R Black, C Shamshuddin]
# 2820              field  United Arab Emirates      [DA Haggo, M Hawthorne]
# 2821                bat  United Arab Emirates      [DA Haggo, M Hawthorne]
#
#                                         info.venue  match_id
# 0           Brisbane Cricket Ground, Woolloongabba         1
# 1                         Melbourne Cricket Ground         2
# 2     Western Australia Cricket Association Ground         3
# 3                            Sydney Cricket Ground         4
# 4                                    Adelaide Oval         5
# ...                                            ...       ...
# 2817          Civil Service Cricket Club, Stormont      2818
# 2818          Civil Service Cricket Club, Stormont      2819
# 2819          Civil Service Cricket Club, Stormont      2820
# 2820     Grange Cricket Club Ground, Raeburn Place      2821
# 2821     Grange Cricket Club Ground, Raeburn Place      2822
#
# [2822 rows x 15 columns]

# %%
# Dropping 'info.balls_per_over' column
dataframe_1 = dataframe_1.drop(columns=['info.balls_per_over'])

# %%
dataframe_1
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...   Brisbane
# 1     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...      Perth
# 3     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 4     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# ...                                                 ...        ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...    Belfast
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...  Edinburgh
# 2821  [{'1st innings': {'team': 'United Arab Emirate...  Edinburgh
#
#         info.dates info.gender info.match_type info.outcome.winner  \
# 0     [2017-01-13]        male             ODI           Australia
# 1     [2017-01-15]        male             ODI            Pakistan
# 2     [2017-01-19]        male             ODI           Australia
# 3     [2017-01-22]        male             ODI           Australia
# 4     [2017-01-26]        male             ODI           Australia
# ...            ...         ...             ...                 ...
# 2817  [2016-07-12]        male             ODI         Afghanistan
# 2818  [2016-07-17]        male             ODI         Afghanistan
# 2819  [2016-07-19]        male             ODI             Ireland
# 2820  [2016-08-14]        male             ODI            Scotland
# 2821  [2016-08-16]        male             ODI            Scotland
#
#       info.overs info.player_of_match                        info.teams  \
# 0             50            [MS Wade]             [Australia, Pakistan]
# 1             50    [Mohammad Hafeez]             [Australia, Pakistan]
# 2             50          [SPD Smith]             [Australia, Pakistan]
# 3             50          [DA Warner]             [Australia, Pakistan]
# 4             50          [DA Warner]             [Australia, Pakistan]
# ...          ...                  ...                               ...
# 2817          50                  NaN            [Ireland, Afghanistan]
# 2818          50                  NaN            [Ireland, Afghanistan]
# 2819          50                  NaN            [Ireland, Afghanistan]
# 2820          50                  NaN  [Scotland, United Arab Emirates]
# 2821          50                  NaN  [Scotland, United Arab Emirates]
#
#      info.toss.decision      info.toss.winner                 info.umpires  \
# 0                   bat             Australia  [MD Martell, C Shamshuddin]
# 1                   bat             Australia      [CB Gaffaney, P Wilson]
# 2                 field             Australia      [SD Fry, C Shamshuddin]
# 3                   bat             Australia    [CB Gaffaney, MD Martell]
# 4                   bat             Australia      [SD Fry, C Shamshuddin]
# ...                 ...                   ...                          ...
# 2817              field               Ireland        [AJ Neill, IN Ramage]
# 2818                bat           Afghanistan    [AJ Neill, C Shamshuddin]
# 2819              field           Afghanistan     [R Black, C Shamshuddin]
# 2820              field  United Arab Emirates      [DA Haggo, M Hawthorne]
# 2821                bat  United Arab Emirates      [DA Haggo, M Hawthorne]
#
#                                         info.venue  match_id
# 0           Brisbane Cricket Ground, Woolloongabba         1
# 1                         Melbourne Cricket Ground         2
# 2     Western Australia Cricket Association Ground         3
# 3                            Sydney Cricket Ground         4
# 4                                    Adelaide Oval         5
# ...                                            ...       ...
# 2817          Civil Service Cricket Club, Stormont      2818
# 2818          Civil Service Cricket Club, Stormont      2819
# 2819          Civil Service Cricket Club, Stormont      2820
# 2820     Grange Cricket Club Ground, Raeburn Place      2821
# 2821     Grange Cricket Club Ground, Raeburn Place      2822
#
# [2822 rows x 14 columns]

# %%
# We need only 'male' data, so checking 'gender' column
dataframe_1['info.gender'].value_counts()
# Out:
# info.gender
# male      2422
# female     400
# Name: count, dtype: int64

# %%
# Dropping 'info.gender' column after extracting only 'male'
dataframe_1 = dataframe_1[dataframe_1['info.gender'] == 'male']
dataframe_1.drop(columns = ['info.gender'],inplace = True)
# Out:
# C:\Users\Bitto\AppData\Local\Temp\ipykernel_6976\1017399414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe_1.drop(columns = ['info.gender'],inplace = True)

# %%
dataframe_1
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...   Brisbane
# 1     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...      Perth
# 3     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 4     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# ...                                                 ...        ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...    Belfast
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...  Edinburgh
# 2821  [{'1st innings': {'team': 'United Arab Emirate...  Edinburgh
#
#         info.dates info.match_type info.outcome.winner  info.overs  \
# 0     [2017-01-13]             ODI           Australia          50
# 1     [2017-01-15]             ODI            Pakistan          50
# 2     [2017-01-19]             ODI           Australia          50
# 3     [2017-01-22]             ODI           Australia          50
# 4     [2017-01-26]             ODI           Australia          50
# ...            ...             ...                 ...         ...
# 2817  [2016-07-12]             ODI         Afghanistan          50
# 2818  [2016-07-17]             ODI         Afghanistan          50
# 2819  [2016-07-19]             ODI             Ireland          50
# 2820  [2016-08-14]             ODI            Scotland          50
# 2821  [2016-08-16]             ODI            Scotland          50
#
#      info.player_of_match                        info.teams  \
# 0               [MS Wade]             [Australia, Pakistan]
# 1       [Mohammad Hafeez]             [Australia, Pakistan]
# 2             [SPD Smith]             [Australia, Pakistan]
# 3             [DA Warner]             [Australia, Pakistan]
# 4             [DA Warner]             [Australia, Pakistan]
# ...                   ...                               ...
# 2817                  NaN            [Ireland, Afghanistan]
# 2818                  NaN            [Ireland, Afghanistan]
# 2819                  NaN            [Ireland, Afghanistan]
# 2820                  NaN  [Scotland, United Arab Emirates]
# 2821                  NaN  [Scotland, United Arab Emirates]
#
#      info.toss.decision      info.toss.winner                 info.umpires  \
# 0                   bat             Australia  [MD Martell, C Shamshuddin]
# 1                   bat             Australia      [CB Gaffaney, P Wilson]
# 2                 field             Australia      [SD Fry, C Shamshuddin]
# 3                   bat             Australia    [CB Gaffaney, MD Martell]
# 4                   bat             Australia      [SD Fry, C Shamshuddin]
# ...                 ...                   ...                          ...
# 2817              field               Ireland        [AJ Neill, IN Ramage]
# 2818                bat           Afghanistan    [AJ Neill, C Shamshuddin]
# 2819              field           Afghanistan     [R Black, C Shamshuddin]
# 2820              field  United Arab Emirates      [DA Haggo, M Hawthorne]
# 2821                bat  United Arab Emirates      [DA Haggo, M Hawthorne]
#
#                                         info.venue  match_id
# 0           Brisbane Cricket Ground, Woolloongabba         1
# 1                         Melbourne Cricket Ground         2
# 2     Western Australia Cricket Association Ground         3
# 3                            Sydney Cricket Ground         4
# 4                                    Adelaide Oval         5
# ...                                            ...       ...
# 2817          Civil Service Cricket Club, Stormont      2818
# 2818          Civil Service Cricket Club, Stormont      2819
# 2819          Civil Service Cricket Club, Stormont      2820
# 2820     Grange Cricket Club Ground, Raeburn Place      2821
# 2821     Grange Cricket Club Ground, Raeburn Place      2822
#
# [2422 rows x 13 columns]

# %%
# We need only '50 overs - ODI MAtch' data, so checking 'match_type' column
dataframe_1['info.match_type'].value_counts()
# Out:
# info.match_type
# ODI    2422
# Name: count, dtype: int64

# %%
# Dropping 'info.overs' column after extracting only '50' overs match data
dataframe_1 = dataframe_1[dataframe_1['info.overs'] == 50]
dataframe_1.drop(columns = ['info.overs','info.match_type'],inplace = True)

# %%
dataframe_1
# Out:
#                                                 innings  info.city  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...   Brisbane
# 1     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 2     [{'1st innings': {'team': 'Pakistan', 'deliver...      Perth
# 3     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# 4     [{'1st innings': {'team': 'Australia', 'delive...        NaN
# ...                                                 ...        ...
# 2817  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2818  [{'1st innings': {'team': 'Afghanistan', 'deli...    Belfast
# 2819  [{'1st innings': {'team': 'Ireland', 'deliveri...    Belfast
# 2820  [{'1st innings': {'team': 'Scotland', 'deliver...  Edinburgh
# 2821  [{'1st innings': {'team': 'United Arab Emirate...  Edinburgh
#
#         info.dates info.outcome.winner info.player_of_match  \
# 0     [2017-01-13]           Australia            [MS Wade]
# 1     [2017-01-15]            Pakistan    [Mohammad Hafeez]
# 2     [2017-01-19]           Australia          [SPD Smith]
# 3     [2017-01-22]           Australia          [DA Warner]
# 4     [2017-01-26]           Australia          [DA Warner]
# ...            ...                 ...                  ...
# 2817  [2016-07-12]         Afghanistan                  NaN
# 2818  [2016-07-17]         Afghanistan                  NaN
# 2819  [2016-07-19]             Ireland                  NaN
# 2820  [2016-08-14]            Scotland                  NaN
# 2821  [2016-08-16]            Scotland                  NaN
#
#                             info.teams info.toss.decision  \
# 0                [Australia, Pakistan]                bat
# 1                [Australia, Pakistan]                bat
# 2                [Australia, Pakistan]              field
# 3                [Australia, Pakistan]                bat
# 4                [Australia, Pakistan]                bat
# ...                                ...                ...
# 2817            [Ireland, Afghanistan]              field
# 2818            [Ireland, Afghanistan]                bat
# 2819            [Ireland, Afghanistan]              field
# 2820  [Scotland, United Arab Emirates]              field
# 2821  [Scotland, United Arab Emirates]                bat
#
#           info.toss.winner                 info.umpires  \
# 0                Australia  [MD Martell, C Shamshuddin]
# 1                Australia      [CB Gaffaney, P Wilson]
# 2                Australia      [SD Fry, C Shamshuddin]
# 3                Australia    [CB Gaffaney, MD Martell]
# 4                Australia      [SD Fry, C Shamshuddin]
# ...                    ...                          ...
# 2817               Ireland        [AJ Neill, IN Ramage]
# 2818           Afghanistan    [AJ Neill, C Shamshuddin]
# 2819           Afghanistan     [R Black, C Shamshuddin]
# 2820  United Arab Emirates      [DA Haggo, M Hawthorne]
# 2821  United Arab Emirates      [DA Haggo, M Hawthorne]
#
#                                         info.venue  match_id
# 0           Brisbane Cricket Ground, Woolloongabba         1
# 1                         Melbourne Cricket Ground         2
# 2     Western Australia Cricket Association Ground         3
# 3                            Sydney Cricket Ground         4
# 4                                    Adelaide Oval         5
# ...                                            ...       ...
# 2817          Civil Service Cricket Club, Stormont      2818
# 2818          Civil Service Cricket Club, Stormont      2819
# 2819          Civil Service Cricket Club, Stormont      2820
# 2820     Grange Cricket Club Ground, Raeburn Place      2821
# 2821     Grange Cricket Club Ground, Raeburn Place      2822
#
# [2422 rows x 11 columns]

# %%
# Going inside the 'innings' to check the data
dataframe_1['innings']
# Out:
# 0       [{'1st innings': {'team': 'Australia', 'delive...
# 1       [{'1st innings': {'team': 'Australia', 'delive...
# 2       [{'1st innings': {'team': 'Pakistan', 'deliver...
# 3       [{'1st innings': {'team': 'Australia', 'delive...
# 4       [{'1st innings': {'team': 'Australia', 'delive...
#                               ...
# 2817    [{'1st innings': {'team': 'Afghanistan', 'deli...
# 2818    [{'1st innings': {'team': 'Afghanistan', 'deli...
# 2819    [{'1st innings': {'team': 'Ireland', 'deliveri...
# 2820    [{'1st innings': {'team': 'Scotland', 'deliver...
# 2821    [{'1st innings': {'team': 'United Arab Emirate...
# Name: innings, Length: 2422, dtype: object

# %%
# Checking how many dictionaries are there in this 'innings' directory
len(dataframe_1.iloc[0]['innings'])
# Out:
# 2

# %%
# Going inside the dictionary
dataframe_1.iloc[0]['innings']
# Out:
# [{'1st innings': {'team': 'Australia',
#    'deliveries': [{0.1: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.2: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.3: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.4: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.5: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'extras': {'wides': 1},
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {0.6: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.7: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.1: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.2: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {1.3: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.4: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.5: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {1.6: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.1: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {2.2: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.3: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {2.4: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {2.5: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {2.6: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {3.1: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {3.2: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {3.3: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {3.4: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {3.5: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {3.6: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {4.1: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {4.2: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'DA Warner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {4.3: {'batsman': 'DA Warner',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'kind': 'bowled', 'player_out': 'DA Warner'}}},
#     {4.4: {'batsman': 'SPD Smith',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['Mohammad Rizwan'],
#        'kind': 'caught',
#        'player_out': 'SPD Smith'}}},
#     {4.5: {'batsman': 'CA Lynn',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {4.6: {'batsman': 'CA Lynn',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {5.1: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {5.2: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {5.3: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {5.4: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#     {5.5: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'extras': {'wides': 1},
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {5.6: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {5.7: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.1: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.2: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.3: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {6.4: {'batsman': 'CA Lynn',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#     {6.5: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {6.6: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {7.1: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {7.2: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {7.3: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {7.4: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {7.5: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#     {7.6: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {8.1: {'batsman': 'CA Lynn',
#       'bowler': 'Wahab Riaz',
#       'extras': {'wides': 1},
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {8.2: {'batsman': 'CA Lynn',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {8.3: {'batsman': 'TM Head',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {8.4: {'batsman': 'TM Head',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {8.5: {'batsman': 'TM Head',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {8.6: {'batsman': 'TM Head',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {8.7: {'batsman': 'TM Head',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'CA Lynn',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {9.1: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {9.2: {'batsman': 'CA Lynn',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['Mohammad Rizwan'],
#        'kind': 'caught',
#        'player_out': 'CA Lynn'}}},
#     {9.3: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {9.4: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {9.5: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {9.6: {'batsman': 'TM Head',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {10.1: {'batsman': 'TM Head',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {10.2: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {10.3: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {10.4: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {10.5: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {10.6: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {11.1: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.2: {'batsman': 'MR Marsh',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {11.3: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {11.4: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {11.5: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {11.6: {'batsman': 'TM Head',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.1: {'batsman': 'TM Head',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {12.2: {'batsman': 'TM Head',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {12.3: {'batsman': 'TM Head',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.4: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {12.5: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'TM Head',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {12.6: {'batsman': 'TM Head',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['Mohammad Rizwan'],
#        'kind': 'caught',
#        'player_out': 'TM Head'}}},
#     {13.1: {'batsman': 'MR Marsh',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {13.2: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {13.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {13.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {13.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {13.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {14.1: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {14.2: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {14.3: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {14.4: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {14.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {14.6: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {15.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {15.2: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {15.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {15.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {15.5: {'batsman': 'MR Marsh',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {15.6: {'batsman': 'MR Marsh',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {16.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MR Marsh',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.2: {'batsman': 'MR Marsh',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['Mohammad Rizwan'],
#        'kind': 'caught',
#        'player_out': 'MR Marsh'}}},
#     {16.3: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.5: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {16.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {17.1: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.2: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.3: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'extras': {'wides': 1},
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {17.4: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {17.5: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {17.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {17.7: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.2: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {18.3: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {18.4: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {18.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {18.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {19.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {19.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {19.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {19.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {19.5: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {19.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {20.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {20.2: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {20.3: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {20.4: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {20.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {20.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {21.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {21.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {21.3: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {21.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {21.5: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {21.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {22.1: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {22.2: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {22.3: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {22.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {22.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {22.6: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {23.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {23.2: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {23.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {23.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {23.5: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {23.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {24.1: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {24.2: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {24.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {24.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {24.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {24.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {25.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {25.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {25.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {25.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {25.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {25.6: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {26.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {26.2: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {26.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {26.4: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {26.5: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {26.6: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {27.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {27.2: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {27.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {27.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {27.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {27.6: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {28.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {28.2: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {28.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {28.4: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {28.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {28.6: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {29.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {29.2: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {29.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {29.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'extras': {'wides': 1},
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {29.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {29.6: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {29.7: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'GJ Maxwell',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {30.1: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {30.2: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'extras': {'wides': 1},
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {30.3: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {30.4: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {30.5: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {30.6: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {30.7: {'batsman': 'GJ Maxwell',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['Mohammad Hafeez'],
#        'kind': 'caught',
#        'player_out': 'GJ Maxwell'}}},
#     {31.1: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'JP Faulkner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.2: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'JP Faulkner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {31.3: {'batsman': 'JP Faulkner',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.4: {'batsman': 'JP Faulkner',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.5: {'batsman': 'JP Faulkner',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.6: {'batsman': 'JP Faulkner',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {32.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'JP Faulkner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {32.2: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Hafeez',
#       'extras': {'wides': 1},
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {32.3: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {32.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'JP Faulkner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {32.5: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {32.6: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {32.7: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {33.1: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {33.2: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {33.3: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'JP Faulkner',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {33.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'JP Faulkner',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {33.5: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {33.6: {'batsman': 'JP Faulkner',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['Mohammad Hafeez'],
#        'kind': 'caught',
#        'player_out': 'JP Faulkner'}}},
#     {34.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {34.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {34.3: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {34.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {34.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {34.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {35.2: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.3: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.4: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {36.1: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {36.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {36.3: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {36.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {36.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {36.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Hafeez',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {37.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {37.2: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {37.3: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {37.4: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {37.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {37.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {38.1: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {38.2: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'extras': {'legbyes': 1},
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {38.3: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {38.4: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {38.5: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {38.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {39.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {39.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {39.3: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {39.4: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {39.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {39.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {40.1: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {40.2: {'batsman': 'MS Wade',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {40.3: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {40.4: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {40.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {40.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Imad Wasim',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {41.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {41.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {41.3: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {41.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {41.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {41.6: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Nawaz (3)',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {42.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'PJ Cummins',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {42.2: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {42.3: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {42.4: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {42.5: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Amir',
#       'extras': {'wides': 1},
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {42.6: {'batsman': 'PJ Cummins',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['Umar Akmal', 'Mohammad Amir'],
#        'kind': 'run out',
#        'player_out': 'PJ Cummins'}}},
#     {42.7: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {43.1: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'extras': {'noballs': 1},
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {43.2: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {43.3: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {43.4: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {43.5: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {43.6: {'batsman': 'MS Wade',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {43.7: {'batsman': 'MA Starc',
#       'bowler': 'Wahab Riaz',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {44.1: {'batsman': 'MA Starc',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {44.2: {'batsman': 'MA Starc',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {44.3: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {44.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {44.5: {'batsman': 'MA Starc',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {44.6: {'batsman': 'MA Starc',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {45.1: {'batsman': 'MA Starc',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {45.2: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MA Starc',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {45.3: {'batsman': 'MA Starc',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {45.4: {'batsman': 'MA Starc',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'kind': 'bowled', 'player_out': 'MA Starc'}}},
#     {45.5: {'batsman': 'B Stanlake',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {45.6: {'batsman': 'B Stanlake',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {46.1: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {46.2: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {46.3: {'batsman': 'B Stanlake',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {46.4: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {46.5: {'batsman': 'MS Wade',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {46.6: {'batsman': 'B Stanlake',
#       'bowler': 'Mohammad Amir',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {47.1: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {47.2: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {47.3: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {47.4: {'batsman': 'MS Wade',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'B Stanlake',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {47.5: {'batsman': 'B Stanlake',
#       'bowler': 'Hasan Ali',
#       'non_striker': 'MS Wade',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
# ...
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {27.1: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Mohammad Rizwan',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {27.2: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {27.3: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {27.4: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {27.5: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {27.6: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {28.1: {'batsman': 'Imad Wasim',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Rizwan',
#       'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#     {28.2: {'batsman': 'Imad Wasim',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Rizwan',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {28.3: {'batsman': 'Imad Wasim',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Rizwan',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {28.4: {'batsman': 'Imad Wasim',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Rizwan',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {28.5: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {28.6: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {29.1: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Mohammad Rizwan',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {29.2: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {29.3: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {29.4: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Mohammad Rizwan',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {29.5: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {29.6: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'TM Head',
#       'extras': {'legbyes': 1},
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {30.1: {'batsman': 'Mohammad Rizwan',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['MR Marsh'],
#        'kind': 'caught',
#        'player_out': 'Mohammad Rizwan'}}},
#     {30.2: {'batsman': 'Imad Wasim',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Nawaz (3)',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {30.3: {'batsman': 'Imad Wasim',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Nawaz (3)',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {30.4: {'batsman': 'Imad Wasim',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Nawaz (3)',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {30.5: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {30.6: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.1: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Mohammad Nawaz (3)',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.2: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Mohammad Nawaz (3)',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.3: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Mohammad Nawaz (3)',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.4: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Mohammad Nawaz (3)',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {31.5: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {31.6: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {32.1: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'MA Starc',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {32.2: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'MA Starc',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {32.3: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'MA Starc',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {32.4: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'MA Starc',
#       'extras': {'wides': 1},
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {32.5: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'MA Starc',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {32.6: {'batsman': 'Mohammad Nawaz (3)',
#       'bowler': 'MA Starc',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'kind': 'bowled', 'player_out': 'Mohammad Nawaz (3)'}}},
#     {32.7: {'batsman': 'Azhar Ali',
#       'bowler': 'MA Starc',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {33.1: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {33.2: {'batsman': 'Azhar Ali',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {33.3: {'batsman': 'Azhar Ali',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {33.4: {'batsman': 'Azhar Ali',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {33.5: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {33.6: {'batsman': 'Azhar Ali',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {34.1: {'batsman': 'Imad Wasim',
#       'bowler': 'MA Starc',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {34.2: {'batsman': 'Imad Wasim',
#       'bowler': 'MA Starc',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {34.3: {'batsman': 'Imad Wasim',
#       'bowler': 'MA Starc',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {34.4: {'batsman': 'Imad Wasim',
#       'bowler': 'MA Starc',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {34.5: {'batsman': 'Imad Wasim',
#       'bowler': 'MA Starc',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {34.6: {'batsman': 'Imad Wasim',
#       'bowler': 'MA Starc',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {35.1: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.2: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.3: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.4: {'batsman': 'Imad Wasim',
#       'bowler': 'TM Head',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {35.5: {'batsman': 'Azhar Ali',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {35.6: {'batsman': 'Azhar Ali',
#       'bowler': 'TM Head',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {36.1: {'batsman': 'Azhar Ali',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {36.2: {'batsman': 'Imad Wasim',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {36.3: {'batsman': 'Imad Wasim',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {36.4: {'batsman': 'Azhar Ali',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {36.5: {'batsman': 'Imad Wasim',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#     {36.6: {'batsman': 'Imad Wasim',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {37.1: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {37.2: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {37.3: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {37.4: {'batsman': 'Imad Wasim',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {37.5: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {37.6: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {38.1: {'batsman': 'Azhar Ali',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Imad Wasim',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {38.2: {'batsman': 'Imad Wasim',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {38.3: {'batsman': 'Imad Wasim',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['DA Warner'],
#        'kind': 'caught',
#        'player_out': 'Imad Wasim'}}},
#     {38.4: {'batsman': 'Azhar Ali',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {38.5: {'batsman': 'Azhar Ali',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {38.6: {'batsman': 'Mohammad Amir',
#       'bowler': 'MR Marsh',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {39.1: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {39.2: {'batsman': 'Mohammad Amir',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {39.3: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {39.4: {'batsman': 'Mohammad Amir',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Azhar Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {39.5: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {39.6: {'batsman': 'Azhar Ali',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['DA Warner'],
#        'kind': 'caught',
#        'player_out': 'Azhar Ali'}}},
#     {40.1: {'batsman': 'Wahab Riaz',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {40.2: {'batsman': 'Mohammad Amir',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {40.3: {'batsman': 'Mohammad Amir',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {40.4: {'batsman': 'Mohammad Amir',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {40.5: {'batsman': 'Mohammad Amir',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {40.6: {'batsman': 'Wahab Riaz',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {41.1: {'batsman': 'Mohammad Amir',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {41.2: {'batsman': 'Wahab Riaz',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Mohammad Amir',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {41.3: {'batsman': 'Mohammad Amir',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {41.4: {'batsman': 'Mohammad Amir',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['GJ Maxwell'],
#        'kind': 'caught',
#        'player_out': 'Mohammad Amir'}}},
#     {41.5: {'batsman': 'Wahab Riaz',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Hasan Ali',
#       'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#     {41.6: {'batsman': 'Wahab Riaz',
#       'bowler': 'JP Faulkner',
#       'non_striker': 'Hasan Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {42.1: {'batsman': 'Wahab Riaz',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Hasan Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {42.2: {'batsman': 'Wahab Riaz',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Hasan Ali',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {42.3: {'batsman': 'Hasan Ali',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Wahab Riaz',
#       'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#     {42.4: {'batsman': 'Wahab Riaz',
#       'bowler': 'PJ Cummins',
#       'non_striker': 'Hasan Ali',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#       'wicket': {'fielders': ['MA Starc'],
#        'kind': 'caught',
#        'player_out': 'Wahab Riaz'}}}]}}]

# %%
# Going inside the 1st - dictionary : 'innings' and found 'deliveries' - another dictionary :
dataframe_1.iloc[0]['innings'][0]
# Out:
# {'1st innings': {'team': 'Australia',
#   'deliveries': [{0.1: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.2: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.3: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.4: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.5: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'extras': {'wides': 1},
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {0.6: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.7: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.1: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.2: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {1.3: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.4: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.5: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {1.6: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {2.1: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {2.2: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {2.3: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {2.4: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {2.5: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {2.6: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {3.1: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {3.2: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {3.3: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {3.4: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {3.5: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {3.6: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {4.1: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {4.2: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'DA Warner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {4.3: {'batsman': 'DA Warner',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'kind': 'bowled', 'player_out': 'DA Warner'}}},
#    {4.4: {'batsman': 'SPD Smith',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['Mohammad Rizwan'],
#       'kind': 'caught',
#       'player_out': 'SPD Smith'}}},
#    {4.5: {'batsman': 'CA Lynn',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {4.6: {'batsman': 'CA Lynn',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {5.1: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {5.2: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {5.3: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {5.4: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#    {5.5: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'extras': {'wides': 1},
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {5.6: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {5.7: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {6.1: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {6.2: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {6.3: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {6.4: {'batsman': 'CA Lynn',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#    {6.5: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {6.6: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {7.1: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {7.2: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {7.3: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {7.4: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {7.5: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#    {7.6: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {8.1: {'batsman': 'CA Lynn',
#      'bowler': 'Wahab Riaz',
#      'extras': {'wides': 1},
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {8.2: {'batsman': 'CA Lynn',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {8.3: {'batsman': 'TM Head',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {8.4: {'batsman': 'TM Head',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {8.5: {'batsman': 'TM Head',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {8.6: {'batsman': 'TM Head',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {8.7: {'batsman': 'TM Head',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'CA Lynn',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.1: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.2: {'batsman': 'CA Lynn',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['Mohammad Rizwan'],
#       'kind': 'caught',
#       'player_out': 'CA Lynn'}}},
#    {9.3: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {9.4: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {9.5: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {9.6: {'batsman': 'TM Head',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {10.1: {'batsman': 'TM Head',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {10.2: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {10.3: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {10.4: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {10.5: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {10.6: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {11.1: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {11.2: {'batsman': 'MR Marsh',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {11.3: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {11.4: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {11.5: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {11.6: {'batsman': 'TM Head',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {12.1: {'batsman': 'TM Head',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.2: {'batsman': 'TM Head',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.3: {'batsman': 'TM Head',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {12.4: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {12.5: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'TM Head',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {12.6: {'batsman': 'TM Head',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['Mohammad Rizwan'],
#       'kind': 'caught',
#       'player_out': 'TM Head'}}},
#    {13.1: {'batsman': 'MR Marsh',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {13.2: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {13.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {13.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {13.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {13.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {14.1: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {14.2: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {14.3: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {14.4: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {14.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {14.6: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {15.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {15.2: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {15.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {15.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {15.5: {'batsman': 'MR Marsh',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {15.6: {'batsman': 'MR Marsh',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {16.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MR Marsh',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.2: {'batsman': 'MR Marsh',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['Mohammad Rizwan'],
#       'kind': 'caught',
#       'player_out': 'MR Marsh'}}},
#    {16.3: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.5: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {16.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {17.1: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {17.2: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {17.3: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'extras': {'wides': 1},
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {17.4: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {17.5: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {17.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {17.7: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {18.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {18.2: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {18.3: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {18.4: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {18.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {18.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {19.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {19.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {19.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {19.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {19.5: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {19.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {20.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {20.2: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {20.3: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {20.4: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {20.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {20.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {21.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {21.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {21.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {21.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {21.5: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {21.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {22.1: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {22.2: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {22.3: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {22.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {22.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {22.6: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {23.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {23.2: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {23.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {23.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {23.5: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {23.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {24.1: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {24.2: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {24.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {24.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {24.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {24.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {25.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {25.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {25.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {25.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {25.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {25.6: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {26.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {26.2: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {26.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {26.4: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {26.5: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {26.6: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {27.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {27.2: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {27.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {27.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {27.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {27.6: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {28.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.2: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.4: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {28.6: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {29.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {29.2: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {29.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {29.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'extras': {'wides': 1},
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {29.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {29.6: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {29.7: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'GJ Maxwell',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {30.1: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {30.2: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'extras': {'wides': 1},
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {30.3: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {30.4: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {30.5: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {30.6: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {30.7: {'batsman': 'GJ Maxwell',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['Mohammad Hafeez'],
#       'kind': 'caught',
#       'player_out': 'GJ Maxwell'}}},
#    {31.1: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'JP Faulkner',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {31.2: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'JP Faulkner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {31.3: {'batsman': 'JP Faulkner',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {31.4: {'batsman': 'JP Faulkner',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {31.5: {'batsman': 'JP Faulkner',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {31.6: {'batsman': 'JP Faulkner',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {32.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'JP Faulkner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {32.2: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Hafeez',
#      'extras': {'wides': 1},
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {32.3: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {32.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'JP Faulkner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {32.5: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {32.6: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {32.7: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {33.1: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {33.2: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {33.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'JP Faulkner',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {33.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'JP Faulkner',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {33.5: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {33.6: {'batsman': 'JP Faulkner',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['Mohammad Hafeez'],
#       'kind': 'caught',
#       'player_out': 'JP Faulkner'}}},
#    {34.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {34.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {34.3: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {34.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {34.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {34.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {35.2: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.3: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.4: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {35.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {36.1: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {36.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {36.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {36.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {36.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {36.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Hafeez',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {37.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {37.2: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {37.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {37.4: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {37.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {37.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {38.1: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {38.2: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'extras': {'legbyes': 1},
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {38.3: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {38.4: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {38.5: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {38.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {39.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {39.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {39.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {39.4: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {39.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {39.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {40.1: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {40.2: {'batsman': 'MS Wade',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {40.3: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {40.4: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {40.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {40.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Imad Wasim',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {41.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {41.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {41.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {41.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {41.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {41.6: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Nawaz (3)',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {42.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'PJ Cummins',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {42.2: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {42.3: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {42.4: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {42.5: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Amir',
#      'extras': {'wides': 1},
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {42.6: {'batsman': 'PJ Cummins',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'fielders': ['Umar Akmal', 'Mohammad Amir'],
#       'kind': 'run out',
#       'player_out': 'PJ Cummins'}}},
#    {42.7: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {43.1: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'extras': {'noballs': 1},
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {43.2: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {43.3: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {43.4: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {43.5: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {43.6: {'batsman': 'MS Wade',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {43.7: {'batsman': 'MA Starc',
#      'bowler': 'Wahab Riaz',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {44.1: {'batsman': 'MA Starc',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {44.2: {'batsman': 'MA Starc',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {44.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {44.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {44.5: {'batsman': 'MA Starc',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {44.6: {'batsman': 'MA Starc',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {45.1: {'batsman': 'MA Starc',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {45.2: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MA Starc',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {45.3: {'batsman': 'MA Starc',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {45.4: {'batsman': 'MA Starc',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#      'wicket': {'kind': 'bowled', 'player_out': 'MA Starc'}}},
#    {45.5: {'batsman': 'B Stanlake',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {45.6: {'batsman': 'B Stanlake',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {46.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {46.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {46.3: {'batsman': 'B Stanlake',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {46.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#    {46.5: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {46.6: {'batsman': 'B Stanlake',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {47.1: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {47.2: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {47.3: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {47.4: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {47.5: {'batsman': 'B Stanlake',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {47.6: {'batsman': 'B Stanlake',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'MS Wade',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {48.1: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {48.2: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {48.3: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'extras': {'wides': 1},
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {48.4: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {48.5: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {48.6: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {48.7: {'batsman': 'MS Wade',
#      'bowler': 'Mohammad Amir',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#    {49.1: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {49.2: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#    {49.3: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {49.4: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {49.5: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#    {49.6: {'batsman': 'MS Wade',
#      'bowler': 'Hasan Ali',
#      'non_striker': 'B Stanlake',
#      'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}]}}

# %%
# Going inside 'deliveries' : 
dataframe_1.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.4: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {0.6: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.7: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.4: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.6: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.2: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.4: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.6: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.3: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.4: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {3.5: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.6: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.1: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'DA Warner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.3: {'batsman': 'DA Warner',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'DA Warner'}}},
#  {4.4: {'batsman': 'SPD Smith',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'SPD Smith'}}},
#  {4.5: {'batsman': 'CA Lynn',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.6: {'batsman': 'CA Lynn',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.1: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.2: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.3: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.4: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#  {5.5: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {5.6: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.7: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.2: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.3: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.4: {'batsman': 'CA Lynn',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {6.5: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.6: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.1: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {7.2: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.3: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {7.4: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.5: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'non_boundary': 1, 'total': 4}}},
#  {7.6: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.1: {'batsman': 'CA Lynn',
#    'bowler': 'Wahab Riaz',
#    'extras': {'wides': 1},
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {8.2: {'batsman': 'CA Lynn',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.3: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {8.4: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {8.5: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {8.6: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.7: {'batsman': 'TM Head',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'CA Lynn',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.1: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.2: {'batsman': 'CA Lynn',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'CA Lynn'}}},
#  {9.3: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.4: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.5: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.6: {'batsman': 'TM Head',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.1: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.2: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.3: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.4: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.5: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.6: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.1: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.2: {'batsman': 'MR Marsh',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.3: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.4: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.5: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.6: {'batsman': 'TM Head',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.1: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.2: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.3: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.4: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.5: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'TM Head',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.6: {'batsman': 'TM Head',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'TM Head'}}},
#  {13.1: {'batsman': 'MR Marsh',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.1: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.2: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.3: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.4: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.6: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {15.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.5: {'batsman': 'MR Marsh',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.6: {'batsman': 'MR Marsh',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MR Marsh',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.2: {'batsman': 'MR Marsh',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Rizwan'],
#     'kind': 'caught',
#     'player_out': 'MR Marsh'}}},
#  {16.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.5: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.1: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.3: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'extras': {'wides': 1},
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {17.4: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.5: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.7: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.4: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {19.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {19.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {20.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {20.4: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {20.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {21.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {21.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {21.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {22.1: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {22.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {22.6: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {23.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {23.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {23.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.1: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {24.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {24.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {24.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {25.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {25.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {25.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {25.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {25.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {25.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {26.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {26.5: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {26.6: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {27.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {27.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {27.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {28.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.6: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {29.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.2: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {29.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {29.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.6: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {29.7: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'GJ Maxwell',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.1: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.2: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {30.3: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {30.4: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.5: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.6: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {30.7: {'batsman': 'GJ Maxwell',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Hafeez'],
#     'kind': 'caught',
#     'player_out': 'GJ Maxwell'}}},
#  {31.1: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.2: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {31.3: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.4: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.5: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {31.6: {'batsman': 'JP Faulkner',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {32.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.2: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {32.3: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.5: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {32.6: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {32.7: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.1: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {33.2: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {33.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'JP Faulkner',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.5: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {33.6: {'batsman': 'JP Faulkner',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Mohammad Hafeez'],
#     'kind': 'caught',
#     'player_out': 'JP Faulkner'}}},
#  {34.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {34.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {34.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {35.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.1: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {36.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {36.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {36.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Hafeez',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {37.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {37.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {37.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.1: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {38.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'extras': {'legbyes': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {38.3: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.5: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {39.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {39.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {39.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.1: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.2: {'batsman': 'MS Wade',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Imad Wasim',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {41.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {41.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {41.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {41.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {41.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {41.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Nawaz (3)',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {42.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'PJ Cummins',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {42.2: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {42.3: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {42.4: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {42.5: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {42.6: {'batsman': 'PJ Cummins',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Umar Akmal', 'Mohammad Amir'],
#     'kind': 'run out',
#     'player_out': 'PJ Cummins'}}},
#  {42.7: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {43.1: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'extras': {'noballs': 1},
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {43.2: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {43.3: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {43.4: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {43.5: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {43.6: {'batsman': 'MS Wade',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {43.7: {'batsman': 'MA Starc',
#    'bowler': 'Wahab Riaz',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {44.1: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.2: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {44.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {44.5: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {44.6: {'batsman': 'MA Starc',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.1: {'batsman': 'MA Starc',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MA Starc',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.3: {'batsman': 'MA Starc',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {45.4: {'batsman': 'MA Starc',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'MA Starc'}}},
#  {45.5: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {45.6: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {46.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {46.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.3: {'batsman': 'B Stanlake',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {46.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.6: {'batsman': 'B Stanlake',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {47.1: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {47.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {47.3: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {47.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {47.5: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {47.6: {'batsman': 'B Stanlake',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'MS Wade',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.1: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.2: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {48.3: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'extras': {'wides': 1},
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {48.4: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.5: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {48.6: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {48.7: {'batsman': 'MS Wade',
#    'bowler': 'Mohammad Amir',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {49.1: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {49.2: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {49.3: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {49.4: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {49.5: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {49.6: {'batsman': 'MS Wade',
#    'bowler': 'Hasan Ali',
#    'non_striker': 'B Stanlake',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}]

# %%
count = 1
dataframe_2 = pd.DataFrame()
dfs_to_concatenate = []

for index, row in dataframe_1.iterrows():
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    toss_winner = []
    toss_decision_from_winner = []
    
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            toss_winner.append(row['info.toss.winner'])
            toss_decision_from_winner.append(row['info.toss.decision'])
            
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    
    loop_df = pd.DataFrame({
        'match_id': match_id,
        'teams': teams,
        'batting_team': batting_team,
        'ball': ball_of_match,
        'batsman': batsman,
        'bowler': bowler,
        'runs': runs,
        'player_dismissed': player_of_dismissed,
        'city': city,
        'venue': venue,
        'toss_winner': toss_winner,
        'toss_decision_from_winner': toss_decision_from_winner
    })
    
    dfs_to_concatenate.append(loop_df)
    count += 1

# Concatenate all DataFrames in the list
dataframe_2 = pd.concat(dfs_to_concatenate, ignore_index=True)

# %%
dataframe_2
# Out:
#         match_id                             teams          batting_team  \
# 0              1             [Australia, Pakistan]             Australia
# 1              1             [Australia, Pakistan]             Australia
# 2              1             [Australia, Pakistan]             Australia
# 3              1             [Australia, Pakistan]             Australia
# 4              1             [Australia, Pakistan]             Australia
# ...          ...                               ...                   ...
# 700171      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700172      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700173      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700174      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700175      2422  [Scotland, United Arab Emirates]  United Arab Emirates
#
#         ball       batsman         bowler  runs player_dismissed       city  \
# 0        0.1     DA Warner  Mohammad Amir     0                0   Brisbane
# 1        0.2     DA Warner  Mohammad Amir     0                0   Brisbane
# 2        0.3     DA Warner  Mohammad Amir     0                0   Brisbane
# 3        0.4     DA Warner  Mohammad Amir     0                0   Brisbane
# 4        0.5     DA Warner  Mohammad Amir     1                0   Brisbane
# ...      ...           ...            ...   ...              ...        ...
# 700171  44.6    Ahmed Raza        CB Sole     0                0  Edinburgh
# 700172  45.1  Fayyaz Ahmed       AC Evans     1                0  Edinburgh
# 700173  45.2    Ahmed Raza       AC Evans     0                0  Edinburgh
# 700174  45.3    Ahmed Raza       AC Evans     0                0  Edinburgh
# 700175  45.4    Ahmed Raza       AC Evans     0       Ahmed Raza  Edinburgh
#
#                                             venue           toss_winner  \
# 0          Brisbane Cricket Ground, Woolloongabba             Australia
# 1          Brisbane Cricket Ground, Woolloongabba             Australia
# 2          Brisbane Cricket Ground, Woolloongabba             Australia
# 3          Brisbane Cricket Ground, Woolloongabba             Australia
# 4          Brisbane Cricket Ground, Woolloongabba             Australia
# ...                                           ...                   ...
# 700171  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700172  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700173  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700174  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700175  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
#
#        toss_decision_from_winner
# 0                            bat
# 1                            bat
# 2                            bat
# 3                            bat
# 4                            bat
# ...                          ...
# 700171                       bat
# 700172                       bat
# 700173                       bat
# 700174                       bat
# 700175                       bat
#
# [700176 rows x 12 columns]

# %%
# Extracting 'bowling_team', from the 'teams' column, as the 'batting_team' is defined already, it's easier to extract the 'bowling_team:
def bowling_team(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
# Applying the 'bowling_team' function to each row of the DataFrame
dataframe_2['bowling_team'] = dataframe_2.apply(bowling_team,axis=1)

# %%
dataframe_2
# Out:
#         match_id                             teams          batting_team  \
# 0              1             [Australia, Pakistan]             Australia
# 1              1             [Australia, Pakistan]             Australia
# 2              1             [Australia, Pakistan]             Australia
# 3              1             [Australia, Pakistan]             Australia
# 4              1             [Australia, Pakistan]             Australia
# ...          ...                               ...                   ...
# 700171      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700172      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700173      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700174      2422  [Scotland, United Arab Emirates]  United Arab Emirates
# 700175      2422  [Scotland, United Arab Emirates]  United Arab Emirates
#
#         ball       batsman         bowler  runs player_dismissed       city  \
# 0        0.1     DA Warner  Mohammad Amir     0                0   Brisbane
# 1        0.2     DA Warner  Mohammad Amir     0                0   Brisbane
# 2        0.3     DA Warner  Mohammad Amir     0                0   Brisbane
# 3        0.4     DA Warner  Mohammad Amir     0                0   Brisbane
# 4        0.5     DA Warner  Mohammad Amir     1                0   Brisbane
# ...      ...           ...            ...   ...              ...        ...
# 700171  44.6    Ahmed Raza        CB Sole     0                0  Edinburgh
# 700172  45.1  Fayyaz Ahmed       AC Evans     1                0  Edinburgh
# 700173  45.2    Ahmed Raza       AC Evans     0                0  Edinburgh
# 700174  45.3    Ahmed Raza       AC Evans     0                0  Edinburgh
# 700175  45.4    Ahmed Raza       AC Evans     0       Ahmed Raza  Edinburgh
#
#                                             venue           toss_winner  \
# 0          Brisbane Cricket Ground, Woolloongabba             Australia
# 1          Brisbane Cricket Ground, Woolloongabba             Australia
# 2          Brisbane Cricket Ground, Woolloongabba             Australia
# 3          Brisbane Cricket Ground, Woolloongabba             Australia
# 4          Brisbane Cricket Ground, Woolloongabba             Australia
# ...                                           ...                   ...
# 700171  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700172  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700173  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700174  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700175  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
#
#        toss_decision_from_winner bowling_team
# 0                            bat     Pakistan
# 1                            bat     Pakistan
# 2                            bat     Pakistan
# 3                            bat     Pakistan
# 4                            bat     Pakistan
# ...                          ...          ...
# 700171                       bat     Scotland
# 700172                       bat     Scotland
# 700173                       bat     Scotland
# 700174                       bat     Scotland
# 700175                       bat     Scotland
#
# [700176 rows x 13 columns]

# %%
# Dropping the 'teams' column from the DataFrame
dataframe_2.drop(columns=['teams'], inplace=True)

# Displaying the updated DataFrame
dataframe_2
# Out:
#         match_id          batting_team  ball       batsman         bowler  \
# 0              1             Australia   0.1     DA Warner  Mohammad Amir
# 1              1             Australia   0.2     DA Warner  Mohammad Amir
# 2              1             Australia   0.3     DA Warner  Mohammad Amir
# 3              1             Australia   0.4     DA Warner  Mohammad Amir
# 4              1             Australia   0.5     DA Warner  Mohammad Amir
# ...          ...                   ...   ...           ...            ...
# 700171      2422  United Arab Emirates  44.6    Ahmed Raza        CB Sole
# 700172      2422  United Arab Emirates  45.1  Fayyaz Ahmed       AC Evans
# 700173      2422  United Arab Emirates  45.2    Ahmed Raza       AC Evans
# 700174      2422  United Arab Emirates  45.3    Ahmed Raza       AC Evans
# 700175      2422  United Arab Emirates  45.4    Ahmed Raza       AC Evans
#
#         runs player_dismissed       city  \
# 0          0                0   Brisbane
# 1          0                0   Brisbane
# 2          0                0   Brisbane
# 3          0                0   Brisbane
# 4          1                0   Brisbane
# ...      ...              ...        ...
# 700171     0                0  Edinburgh
# 700172     1                0  Edinburgh
# 700173     0                0  Edinburgh
# 700174     0                0  Edinburgh
# 700175     0       Ahmed Raza  Edinburgh
#
#                                             venue           toss_winner  \
# 0          Brisbane Cricket Ground, Woolloongabba             Australia
# 1          Brisbane Cricket Ground, Woolloongabba             Australia
# 2          Brisbane Cricket Ground, Woolloongabba             Australia
# 3          Brisbane Cricket Ground, Woolloongabba             Australia
# 4          Brisbane Cricket Ground, Woolloongabba             Australia
# ...                                           ...                   ...
# 700171  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700172  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700173  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700174  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
# 700175  Grange Cricket Club Ground, Raeburn Place  United Arab Emirates
#
#        toss_decision_from_winner bowling_team
# 0                            bat     Pakistan
# 1                            bat     Pakistan
# 2                            bat     Pakistan
# 3                            bat     Pakistan
# 4                            bat     Pakistan
# ...                          ...          ...
# 700171                       bat     Scotland
# 700172                       bat     Scotland
# 700173                       bat     Scotland
# 700174                       bat     Scotland
# 700175                       bat     Scotland
#
# [700176 rows x 12 columns]

# %%
# Retrieving the unique values in the 'batting_team' column of DataFrame dataframe_2
dataframe_2['batting_team'].unique()
# Out:
# array(['Australia', 'Pakistan', 'Afghanistan', 'Scotland', 'Zimbabwe',
#        'New Zealand', 'Bangladesh', 'South Africa', 'India', 'England',
#        'Sri Lanka', 'Hong Kong', 'Papua New Guinea', 'West Indies',
#        'Ireland', 'United Arab Emirates', 'Nepal',
#        'United States of America', 'Namibia', 'Oman', 'Netherlands',
#        'Canada', 'Jersey', 'Africa XI', 'Kenya', 'Bermuda', 'Asia XI'],
#       dtype=object)

# %%
# Number of counties
len(dataframe_2['batting_team'].unique())
# Out:
# 27

# %%
# List of cricket teams
teams = [
    'Australia',
    'Pakistan',
    'Afghanistan',
    'Scotland',
    'Zimbabwe',
    'New Zealand',
    'Bangladesh',
    'South Africa',
    'India',
    'England',
    'Sri Lanka',
    'West Indies',
    'Ireland',
    'Netherlands',
    'Kenya'
]

# %%
len(teams)
# Out:
# 15

# %%
# Filtering DataFrame to include only rows where 'batting_team' is in the provided list of teams
dataframe_2 = dataframe_2[dataframe_2['batting_team'].isin(teams)]

# Further filtering DataFrame to include only rows where 'bowling_team' is in the provided list of teams
dataframe_2 = dataframe_2[dataframe_2['bowling_team'].isin(teams)]

# %%
dataframe_2
# Out:
#         match_id batting_team  ball     batsman         bowler  runs  \
# 0              1    Australia   0.1   DA Warner  Mohammad Amir     0
# 1              1    Australia   0.2   DA Warner  Mohammad Amir     0
# 2              1    Australia   0.3   DA Warner  Mohammad Amir     0
# 3              1    Australia   0.4   DA Warner  Mohammad Amir     0
# 4              1    Australia   0.5   DA Warner  Mohammad Amir     1
# ...          ...          ...   ...         ...            ...   ...
# 699581      2420      Ireland  49.2    EC Joyce    Rashid Khan     4
# 699582      2420      Ireland  49.3    EC Joyce    Rashid Khan     4
# 699583      2420      Ireland  49.4    EC Joyce    Rashid Khan     1
# 699584      2420      Ireland  49.5  SW Poynter    Rashid Khan     1
# 699585      2420      Ireland  49.6    EC Joyce    Rashid Khan     0
#
#        player_dismissed      city                                   venue  \
# 0                     0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 1                     0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 2                     0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 3                     0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# 4                     0  Brisbane  Brisbane Cricket Ground, Woolloongabba
# ...                 ...       ...                                     ...
# 699581                0   Belfast    Civil Service Cricket Club, Stormont
# 699582                0   Belfast    Civil Service Cricket Club, Stormont
# 699583                0   Belfast    Civil Service Cricket Club, Stormont
# 699584                0   Belfast    Civil Service Cricket Club, Stormont
# 699585                0   Belfast    Civil Service Cricket Club, Stormont
#
#         toss_winner toss_decision_from_winner bowling_team
# 0         Australia                       bat     Pakistan
# 1         Australia                       bat     Pakistan
# 2         Australia                       bat     Pakistan
# 3         Australia                       bat     Pakistan
# 4         Australia                       bat     Pakistan
# ...             ...                       ...          ...
# 699581  Afghanistan                     field  Afghanistan
# 699582  Afghanistan                     field  Afghanistan
# 699583  Afghanistan                     field  Afghanistan
# 699584  Afghanistan                     field  Afghanistan
# 699585  Afghanistan                     field  Afghanistan
#
# [618005 rows x 12 columns]

# %%
# Taking the features only, which are needed for the prediction
features_needed = dataframe_2[['match_id','batting_team','bowling_team','toss_winner','toss_decision_from_winner','ball','runs','player_dismissed','city','venue']]

# %%
features_needed
# Out:
#         match_id batting_team bowling_team  toss_winner  \
# 0              1    Australia     Pakistan    Australia
# 1              1    Australia     Pakistan    Australia
# 2              1    Australia     Pakistan    Australia
# 3              1    Australia     Pakistan    Australia
# 4              1    Australia     Pakistan    Australia
# ...          ...          ...          ...          ...
# 699581      2420      Ireland  Afghanistan  Afghanistan
# 699582      2420      Ireland  Afghanistan  Afghanistan
# 699583      2420      Ireland  Afghanistan  Afghanistan
# 699584      2420      Ireland  Afghanistan  Afghanistan
# 699585      2420      Ireland  Afghanistan  Afghanistan
#
#        toss_decision_from_winner  ball  runs player_dismissed      city  \
# 0                            bat   0.1     0                0  Brisbane
# 1                            bat   0.2     0                0  Brisbane
# 2                            bat   0.3     0                0  Brisbane
# 3                            bat   0.4     0                0  Brisbane
# 4                            bat   0.5     1                0  Brisbane
# ...                          ...   ...   ...              ...       ...
# 699581                     field  49.2     4                0   Belfast
# 699582                     field  49.3     4                0   Belfast
# 699583                     field  49.4     1                0   Belfast
# 699584                     field  49.5     1                0   Belfast
# 699585                     field  49.6     0                0   Belfast
#
#                                          venue
# 0       Brisbane Cricket Ground, Woolloongabba
# 1       Brisbane Cricket Ground, Woolloongabba
# 2       Brisbane Cricket Ground, Woolloongabba
# 3       Brisbane Cricket Ground, Woolloongabba
# 4       Brisbane Cricket Ground, Woolloongabba
# ...                                        ...
# 699581    Civil Service Cricket Club, Stormont
# 699582    Civil Service Cricket Club, Stormont
# 699583    Civil Service Cricket Club, Stormont
# 699584    Civil Service Cricket Club, Stormont
# 699585    Civil Service Cricket Club, Stormont
#
# [618005 rows x 10 columns]

# %%
import pickle

# Serialize and save the 'features_needed' DataFrame to a binary file named 'odi_data_extract.pkl'
pickle.dump(features_needed, open('odi_data_extract.pkl', 'wb'))
